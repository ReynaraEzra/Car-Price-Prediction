# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Data

# %%
path = "Price_Car.csv"
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df = df.replace("?",np.nan)

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    164 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         203 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 201 non-null object
# stroke               201 non-null object
# ...

# %%
rata_normalized = df['normalized-losses'].astype('float').mean()
df['normalized-losses'].replace(np.nan, rata_normalized, inplace=True)

# %%
df['num-of-doors'].replace(np.nan, "four", inplace=True)

# %%
rata_bore = df['bore'].astype('float').mean()
df['bore'].replace(np.nan, rata_bore, inplace=True)

# %%
rata_stroke = df['stroke'].astype('float').mean()
df['stroke'].replace(np.nan, rata_stroke, inplace=True)

# %%
rata_horsepower = df['horsepower'].astype('float').mean()
df['horsepower'].replace(np.nan, rata_horsepower, inplace=True)

# %%
rata_peak = df['peak-rpm'].astype('float').mean()
df['peak-rpm'].replace(np.nan, rata_peak, inplace=True)

# %%
df.dropna(subset=["price"], axis=0, inplace=True)

# %%
df[["bore", "stroke"]] = df[["bore", "stroke"]].astype("float")
df[["normalized-losses"]] = df[["normalized-losses"]].astype("int")
df[["price"]] = df[["price"]].astype("float")
df[["peak-rpm"]] = df[["peak-rpm"]].astype("float")
df[["horsepower"]] = df[["horsepower"]].astype("float")

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses      int32
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
df.to_csv('CleanData_Price_Car.csv')

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Normalized-Losses vs Price

# %%
df[['normalized-losses','price']].corr()
# Out:
#                    normalized-losses     price
# normalized-losses           1.000000  0.133999
# price                       0.133999  1.000000

# %%
plt.scatter('normalized-losses','price', data=df)
plt.xlabel('Normalized-losses')
plt.ylabel('Price')
plt.title('Scatter Plot Normalized-losses and Price')
plt.show()

# %%
sns.regplot('normalized-losses', 'price', data=df)
plt.show()

# %% [markdown]
# ### Wheel-Base vs Price

# %%
df[['wheel-base','price']].corr()
# Out:
#             wheel-base     price
# wheel-base    1.000000  0.584642
# price         0.584642  1.000000

# %%
plt.scatter('wheel-base', 'price', data=df)
plt.xlabel('Wheel-base')
plt.ylabel('Price')
plt.title('Scatter Plot Wheel-Base and Price')
plt.show()

# %%
sns.regplot('wheel-base', 'price', data=df)
plt.show()

# %% [markdown]
# ### Length vs Price

# %%
df[['length','price']].corr()
# Out:
#           length     price
# length  1.000000  0.690628
# price   0.690628  1.000000

# %%
plt.scatter('length', 'price', data=df)
plt.xlabel('Length')
plt.ylabel('Price')
plt.title('Scatter Plot Length and Price')
plt.show()

# %%
sns.regplot('length', 'price', data=df)
plt.show()

# %% [markdown]
# ### Width vs Price

# %%
df[['width', 'price']].corr()
# Out:
#           width     price
# width  1.000000  0.751265
# price  0.751265  1.000000

# %%
plt.scatter('width', 'price', data=df)
plt.xlabel('width')
plt.ylabel('Price')
plt.title('Scatter Plot Width and Price')
plt.show()

# %%
sns.regplot('width', 'price', data=df)
plt.show()

# %% [markdown]
# ### Height vs Price

# %%
df[['height', 'price']].corr()
# Out:
#           height     price
# height  1.000000  0.135486
# price   0.135486  1.000000

# %%
plt.scatter('height', 'price', data=df)
plt.xlabel('height')
plt.ylabel('Price')
plt.title('Scatter Plot Height and Price')
plt.show()

# %%
sns.regplot('height', 'price', data=df)
plt.show()

# %% [markdown]
# ### Curb-weight vs Price

# %%
df[['curb-weight', 'price']].corr()
# Out:
#              curb-weight     price
# curb-weight     1.000000  0.834415
# price           0.834415  1.000000

# %%
plt.scatter('curb-weight', 'price', data=df)
plt.xlabel('curb-weight')
plt.ylabel('Price')
plt.title('Scatter Plot Curb-weight and Price')
plt.show()

# %%
sns.regplot('curb-weight', 'price', data=df)
plt.show()

# %% [markdown]
# ### Engine Size vs Price

# %%
df[['engine-size', 'price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
plt.scatter('engine-size', 'price', data=df)
plt.xlabel('Engine-size')
plt.ylabel('Price')
plt.title('Scatter Plot Engine-size and Price')
plt.show()

sns.regplot('engine-size', 'price', data=df)
plt.show()

# %% [markdown]
# ### Bore vs Price

# %%
print(df[['bore', 'price']].corr())

plt.scatter('bore', 'price', data=df)
plt.xlabel('bore')
plt.ylabel('Price')
plt.title('Scatter Plot Bore and Price')
plt.show()

sns.regplot('bore', 'price', data=df)
plt.show()
# Out:
#            bore     price
# bore   1.000000  0.543155
# price  0.543155  1.000000

# %% [markdown]
# ### Stroke vs Price

# %%
print(df[['stroke', 'price']].corr())

plt.scatter('stroke', 'price', data=df)
plt.xlabel('Stroke')
plt.ylabel('Price')
plt.title('Scatter Plot Stroke and Price')
plt.show()

sns.regplot('stroke', 'price', data=df)
plt.show()
# Out:
#           stroke     price
# stroke  1.000000  0.082269
# price   0.082269  1.000000

# %% [markdown]
# ### Compression-ratio vs Price

# %%
print(df[['compression-ratio', 'price']].corr())

plt.scatter('compression-ratio', 'price', data=df)
plt.xlabel('Compression-ratio')
plt.ylabel('Price')
plt.title('Scatter Plot Compression-ratio and Price')
plt.show()

sns.regplot('compression-ratio', 'price', data=df)
plt.show()
# Out:
#                    compression-ratio     price
# compression-ratio           1.000000  0.071107
# price                       0.071107  1.000000

# %% [markdown]
# ### Horsepower vs Price

# %%
print(df[['horsepower', 'price']].corr())

plt.scatter('horsepower', 'price', data=df)
plt.xlabel('Horsepower')
plt.ylabel('Price')
plt.title('Scatter Plot Horsepower and Price')
plt.show()

sns.regplot('horsepower', 'price', data=df)
plt.show()
# Out:
#             horsepower     price
# horsepower    1.000000  0.809575
# price         0.809575  1.000000

# %% [markdown]
# ### Peak-rpm vs Price

# %%
print(df[['peak-rpm', 'price']].corr())

plt.scatter('peak-rpm', 'price', data=df)
plt.xlabel('Peak-rpm')
plt.ylabel('Price')
plt.title('Scatter Plot Peak-rpm and Price')
plt.show()

sns.regplot('peak-rpm', 'price', data=df)
plt.show()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
# ### City-mpg vs Price

# %%
print(df[['city-mpg', 'price']].corr())

plt.scatter('city-mpg', 'price', data=df)
plt.xlabel('City-mpg')
plt.ylabel('Price')
plt.title('Scatter Plot City-mpg and Price')
plt.show()

sns.regplot('city-mpg', 'price', data=df)
plt.show()
# Out:
#           city-mpg     price
# city-mpg  1.000000 -0.686571
# price    -0.686571  1.000000

# %% [markdown]
# ### Highway-mpg vs Price

# %%
print(df[['highway-mpg', 'price']].corr())

plt.scatter('highway-mpg', 'price', data=df)
plt.xlabel('Highway-mpg')
plt.ylabel('Price')
plt.title('Scatter Plot Highway-mpg and Price')
plt.show()

sns.regplot('highway-mpg', 'price', data=df)
plt.show()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# ### Make vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(y="make", x="price", data=df)
plt.xlabel('Price', fontsize=15)
plt.ylabel('Make', fontsize=15)
plt.title('Boxplot Make', fontsize=25)
plt.show()

# %% [markdown]
# ### Body-style vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="body-style", y="price", data=df)
plt.xlabel('Body-style', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Body-style', fontsize=20)
plt.show()

# %% [markdown]
# ### Symboling vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="symboling", y="price", data=df)
plt.xlabel('Symboling', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Symboling', fontsize=20)
plt.show()

# %% [markdown]
# ### Fuel-type vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="fuel-type", y="price", data=df)
plt.xlabel('Fuel-type', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Fuel-type', fontsize=20)
plt.show()

# %% [markdown]
# ### Aspiration vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="aspiration", y="price", data=df)
plt.xlabel('Aspiration', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Aspiration', fontsize=20)
plt.show()

# %% [markdown]
# ### Num-of-doors vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="num-of-doors", y="price", data=df)
plt.xlabel('Num-of-doors', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot num-of-doors', fontsize=20)
plt.show()

# %% [markdown]
# ### Drive-wheels vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="drive-wheels", y="price", data=df)
plt.xlabel('Drive-wheels', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Drive-wheels', fontsize=20)
plt.show()

# %% [markdown]
# ### Engine-location vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="engine-location", y="price", data=df)
plt.xlabel('Engine-location', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Engine-location', fontsize=20)
plt.show()

# %% [markdown]
# ### Engine-type vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="engine-type", y="price", data=df)
plt.xlabel('Engine-type', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Engine-type', fontsize=20)
plt.show()

# %% [markdown]
# ### Num-of-cylinder vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="num-of-cylinders", y="price", data=df)
plt.xlabel('Num-of-cylinders', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Num-of-cylinders', fontsize=20)
plt.show()

# %% [markdown]
# ### Fuel-system vs Price

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="fuel-system", y="price", data=df)
plt.xlabel('Fuel-system', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Fuel-system', fontsize=20)
plt.show()

# %% [markdown]
# ### Compression-Ratio vs Price

# %%
bins = np.linspace(min(df["compression-ratio"]), max(df["compression-ratio"]), 3)

# %%
df['compression-ratio-binned'] = pd.cut(df['compression-ratio'], bins, labels=['Low', 'High'], include_lowest=True)
df[['compression-ratio','compression-ratio-binned']].head()
# Out:
#    compression-ratio compression-ratio-binned
# 0                9.0                      Low
# 1                9.0                      Low
# 2                9.0                      Low
# 3               10.0                      Low
# 4                8.0                      Low

# %%
df['compression-ratio-binned'].value_counts()
# Out:
# Low     181
# High     20
# Name: compression-ratio-binned, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="compression-ratio-binned", y="price", data=df)
plt.xlabel('Compression-ratio-binned', fontsize=15)
plt.ylabel('Price', fontsize=15)
plt.title('Boxplot Compression-ratio-binned', fontsize=20)
plt.show()
